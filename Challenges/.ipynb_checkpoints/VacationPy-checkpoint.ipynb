# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import xarray as xr
import hvplot.xarray  # noqa
import cartopy.crs as ccrs
# Import API key
from api_keys import geoapify_key
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("/Users/sully/Desktop/python-api-challenge/output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  west island -12.1568   96.8225     24.99        83          75
# 1        1     kayangel   8.0823  134.7173     27.77        77          32
# 2        2     waitangi -43.9535 -176.5597      9.34        83          94
# 3        3    grytviken -54.2811  -36.5092     -7.22        65           3
# 4        4    adamstown -25.0660 -130.1015     18.82        72          40
#
#    Wind Speed Country        Date
# 0        6.17      CC  1691610592
# 1        7.93      PW  1691610765
# 2        2.24      NZ  1691611105
# 3        3.35      GS  1691610753
# 4        9.61      PN  1691610574

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
coordinates = {
    "latitude": city_data_df["Lat"],
    "longitude": city_data_df["Lng"],
    "city": city_data_df["City"],
    "humidity": city_data_df["Humidity"]
}
coordinates_df = pd.DataFrame(coordinates)
coordinates_df
# Out:
#      latitude  longitude             city  humidity
# 0    -12.1568    96.8225      west island        83
# 1      8.0823   134.7173         kayangel        77
# 2    -43.9535  -176.5597         waitangi        83
# 3    -54.2811   -36.5092        grytviken        65
# 4    -25.0660  -130.1015        adamstown        72
# ..        ...        ...              ...       ...
# 564   13.9256   -90.8244  puerto san jose        67
# 565   44.3114   -96.7984        brookings        59
# 566   39.3558    -9.3811          peniche        92
# 567   42.5251   -71.7598       leominster        52
# 568   29.5833    74.3167      hanumangarh        41
#
# [569 rows x 4 columns]

# %%
# %%capture --no-display


# Configure the map plot
coordinates_df = pd.DataFrame(coordinates)

# Display the map

map_plot_1 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    color ="city",
    size = "humidity")

map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (city,humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
clean_city_df = city_data_df.dropna()

# Display sample data
clean_city_df.sample(5)
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 305      305          sabalgarh  26.2500   77.4000     27.38        73
# 15        15  port-aux-francais -49.3500   70.2167      2.41        79
# 409      409           chul'man  56.8479  124.9104     13.27        86
# 395      395               bima  -8.4667  118.7167     20.46        93
# 134      134          talladega  33.4359  -86.1058     31.97        66
#
#      Cloudiness  Wind Speed Country        Date
# 305          94        5.59      IN  1691611137
# 15           87       12.29      TF  1691610751
# 409          24        2.28      RU  1691611151
# 395          37        1.55      ID  1691611149
# 134           0        3.09      US  1691611119

# %%
sjs_criteria_df = clean_city_df[clean_city_df["Humidity"] < 60]
sjs_criteria_df.sample(5)
# Out:
#      City_ID                 City      Lat      Lng  Max Temp  Humidity  \
# 36        36             qusmuryn  52.4503  64.6311     20.00        58
# 237      237                 ghat  24.9647  10.1728     32.61        13
# 347      347             kreminna  49.0495  38.2179     21.39        54
# 131      131               maamba -17.3667  27.1500     16.68        41
# 201      201  izucar de matamoros  18.6000 -98.4667     30.52        36
#
#      Cloudiness  Wind Speed Country        Date
# 36          100        5.61      KZ  1691611108
# 237           0        7.01      LY  1691611130
# 347          33        4.35      UA  1691611141
# 131           0        1.63      ZM  1691611118
# 201          43        2.54      MX  1691611126

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = sjs_criteria_df[["City", "Country", "Lat", "Lng", "Humidity"]]
hotel_df

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = None

# Display sample data
hotel_df.sample(5)
# Out:
#               City Country      Lat      Lng  Humidity Hotel Name
#